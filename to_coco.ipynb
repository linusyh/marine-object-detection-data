# %%
from pathlib import Path
from datetime import datetime
import shutil

# %%
image_dir = Path("images")
output_dir = Path("coco")
if not output_dir.exists():
    output_dir.mkdir(parents=True)

# %%
xml_files = list(image_dir.glob("**/*.xml"))
for p in xml_files:
    image_path= None
    if p.with_suffix(".jpg").exists():
        image_path = p.with_suffix(".jpg")
    elif p.with_suffix(".png").exists():
        image_path = p.with_suffix(".png")

    #shutil.copy(image_path, output_dir)
    #shutil.copy(p, output_dir)
    pass

# %%
coco_dir = output_dir # next working directory

# %%
def get_concept_lookup(dir: Path, skipped_folders=[".metadata"]):
    d = {}
    for p in dir.glob("*"):
        if not p.is_dir() or p.name in skipped_folders:
            continue
        print(f"Processing {p}")
        superconcept = p.name.lower()
        for subdir in p.glob("**/"):
            concept = subdir.name
            if concept in d.keys():
                print(f"Conflict: {concept} found in both {d[concept]} and {superconcept}.")
                print(f"=> {d[concept]} overwritten.")
            d[concept] = superconcept
        d[superconcept] = superconcept
    return d

cpt_lkup = get_concept_lookup(image_dir)
# Out:
# Processing images/Sea_Pigs
# Processing images/Sea_cucumbers
# Processing images/Soft_corals
# Processing images/Stony_corals
# Processing images/Black_corals
# Processing images/Starfish
# Processing images/Sea_pens
# Processing images/Sea_anemones
# Processing images/Demosponges
# Processing images/Glass_sponges
# Processing images/Sea_urchins

# %%
len(cpt_lkup)
# Out:
# 446

# %%
info = {
    "year": 2022,
    "version": 1,
    "description": "A dataset of images of sessile benthos, derived from Fathomnet",
    "contributor": "Fathomnet, compiled by Linus Leong",
    "url": "",
    "data_created": datetime.now().isoformat()
}

licenses = [dict(id=0, name="FathomNet", url="https://fathomnet.org/")]

# %%
categories = []

for index, (cpt, supercpt) in enumerate(cpt_lkup.items()):
    new_cat = dict(
        id=index,
        name=cpt,
        supercategory=supercpt,
        isthing=1,
        color=[0,0,0]
    )
    categories.append(new_cat)

categories.append(dict(
    id=-1,
    name="other",
    supercategory="other",
    isthing=1,
    color=[0,0,0]
))

# %%
import matplotlib.pyplot as plt

colors = plt.colormaps.get("tab20").colors
colors = [[int(cc * 255) for cc in c] for c in colors]
supercategories = []

for index, supercpt in enumerate(set(cpt_lkup.values())):
    supercategories.append(
        dict(
            id=index,
            name=supercpt,
            colors=list(colors[index])
        )
    )

# %%
supercategories
# Out:
# [{'id': 0, 'name': 'sea_pigs', 'colors': [31, 119, 180]},
#  {'id': 1, 'name': 'stony_corals', 'colors': [174, 199, 232]},
#  {'id': 2, 'name': 'sea_pens', 'colors': [255, 127, 14]},
#  {'id': 3, 'name': 'sea_anemones', 'colors': [255, 187, 120]},
#  {'id': 4, 'name': 'starfish', 'colors': [44, 160, 44]},
#  {'id': 5, 'name': 'sea_cucumbers', 'colors': [152, 223, 138]},
#  {'id': 6, 'name': 'black_corals', 'colors': [214, 39, 40]},
#  {'id': 7, 'name': 'sea_urchins', 'colors': [255, 152, 150]},
#  {'id': 8, 'name': 'demosponges', 'colors': [148, 103, 189]},
#  {'id': 9, 'name': 'glass_sponges', 'colors': [197, 176, 213]},
#  {'id': 10, 'name': 'soft_corals', 'colors': [140, 86, 75]}]

# %%
from tqdm.autonotebook import tqdm
import xmltodict

xml_files = list(coco_dir.glob("*.xml"))
xml_dicts = []
for x in tqdm(xml_files):
    try:
        xml_dicts.append(xmltodict.parse(x.read_text()))
    except Exception as e:
        print(e)
        print(x)
# Out:
# HBox(children=(IntProgress(value=0, max=25171), HTML(value='')))

# %%
unclassed_labels = set()
for d in xml_dicts:
    obj = d['annotation']["object"]
    if not isinstance(obj, list):
        obj = [obj]
    for a in obj:
        if a["name"] not in cpt_lkup.keys():
            unclassed_labels.add(a["name"])

# %%
import requests

def read_children(json_data: dict, depth=5, start=1):
    children = []
    layer = start
    while "children" in json_data.keys() \
    and "name" in json_data.keys() \
    and layer < depth:
        if layer >= start:
            children.append(json_data["name"])
        json_data = json_data["children"][0]
        layer += 1
    return children

# %%
unclassed_details = {}
for i, other_cpt in enumerate(unclassed_labels):
    print(i)
    res = requests.get(f"https://fathomnet.org/dsg/phylogeny/up/{test_label}")
    if res.status_code != 200:
        print(other_cpt)
        continue
    
    unclassed_details[other_cpt] = read_children(res.json())

# %%
foo = [{} for _ in range(4)]
for cpt, fours in unclassed_details.items():
    for a, b in zip(foo, fours):
        if not b in a.keys():
            a[b] = []
        a[b].append(cpt)

# %%
concept_id_lkup = {x['name']: x['id'] for x in categories}
concept_id_lkup
# Out:
# {'Sea_Pigs': 0,
#  'Elpidiidae': 1,
#  'Scotoplanes': 2,
#  'Scotoplanes_globosa': 3,
#  'Scotoplanes_clarki': 4,
#  'Scotoplanes_sp._A': 5,
#  'Peniagone': 6,
#  'Peniagone_gracilis': 7,
#  'Peniagone_sp._A': 8,
#  'Peniagone_papillata': 9,
#  'Peniagone_sp._1': 10,
#  'Peniagone_vitrea': 11,
#  'Peniagone_sp._2': 12,
#  'Peniagone_vitrea-_sp._1_complex': 13,
#  'Elpidia': 14,
#  'Elpidia_sp._A': 15,
#  'sea_pigs': 16,
#  'Sea_cucumbers': 17,
#  'Holothuroidea': 18,
#  'Elasipodida': 19,
#  'Psychropotidae': 20,
#  'Benthodytes': 21,
#  'Benthodytes_sp._1': 22,
#  'Psychropotes': 23,
#  'Psychropotes_sp._1': 24,
#  'Psychropotes_depressa': 25,
#  'Laetmogonidae': 26,
#  'Pannychia': 27,
#  'Pannychia_moseleyi': 28,
#  'Pannychia_sp._1': 29,
#  'Laetmogone': 30,
#  'Laetmogone_wyvillethomsoni': 31,
#  'Psychronaetes': 32,
#  'Pelagothuriidae': 33,
#  'Enypniastes': 34,
#  'Dendrochirotida': 35,
#  'Cucumariidae': 36,
#  'Abyssocucumis': 37,
#  'Abyssocucumis_abyssorum': 38,
#  'Psolidae': 39,
#  'Psolus': 40,
#  'Psolus_squamatus': 41,
#  'Holothuroidea_sp._4': 42,
#  'Holothuroidea_sp._3': 43,
#  'Holothuroidea_sp._6': 44,
#  'Persiculida': 45,
#  'Pseudostichopus': 46,
#  'Pseudostichopus_mollis': 47,
#  'Benthothuria': 48,
#  'Synallactida': 49,
#  'Deimatidae': 50,
#  'Oneirophanta': 51,
#  'Oneirophanta_mutabilis_complex': 52,
#  'Stichopodidae': 53,
#  'Apostichopus': 54,
#  'Apostichopus_leukothele': 55,
#  'Apostichopus_californicus': 56,
#  'Synallactidae': 57,
#  'Paelopatides': 58,
#  'Paelopatides_confundens': 59,
#  'Bathyplotes': 60,
#  'Synallactes': 61,
#  'Synallactidae_gen._et_sp._indet': 62,
#  'sea_cucumbers': 63,
#  'Soft_corals': 64,
#  'Alcyonacea': 65,
#  'Scleraxonia': 66,
#  'Paragorgiidae': 67,
#  'Paragorgia': 68,
#  'Paragorgia_arborea': 69,
#  'Paragorgia_sp._1': 70,
#  'Sibogagorgia': 71,
#  'Sibogagorgia_cauliflora': 72,
#  'Coralliidae': 73,
#  'Corallium': 74,
#  'Holaxonia': 75,
#  'Acanthogorgiidae': 76,
#  'Acanthogorgia': 77,
#  'Plexauridae': 78,
#  'Swiftia': 79,
#  'Swiftia_kofoidi': 80,
#  'Swiftia_simplex': 81,
#  'Gorgoniidae': 82,
#  'Leptogorgia': 83,
#  'Calcaxonia': 84,
#  'Primnoidae': 85,
#  'Narella': 86,
#  'Narella_bowersi': 87,
#  'Parastenella': 88,
#  'Calyptrophora': 89,
#  'Isididae': 90,
#  'Isidella': 91,
#  'Isidella_tentaculum': 92,
#  'Keratoisis': 93,
#  'Acanella': 94,
#  'Lepidisis': 95,
#  'Chrysogorgiidae': 96,
#  'Iridogorgia': 97,
#  'Chrysogorgia': 98,
#  'Chrysogorgia_pinnata': 99,
#  'Chrysogorgia_monticola': 100,
#  'Alcyoniina': 101,
#  'Alcyoniidae': 102,
#  'Anthomastus': 103,
#  'Heteropolypus': 104,
#  'Heteropolypus_ritteri': 105,
#  'Bathyalcyon': 106,
#  'Bathyalcyon_robustum': 107,
#  'Nephtheidae': 108,
#  'Gersemia': 109,
#  'Gersemia_juliepackardae': 110,
#  'Stolonifera': 111,
#  'Clavulariidae': 112,
#  'Clavularia': 113,
#  'soft_corals': 114,
#  'Stony_corals': 115,
#  'Scleractinia': 116,
#  'Dendrophylliidae': 117,
#  'Balanophyllia': 118,
#  'Caryophylliidae': 119,
#  'Caryophyllia': 120,
#  'Desmophyllum': 121,
#  'Desmophyllum_dianthus': 122,
#  'Fungiidae': 123,
#  'Fungiacyathus': 124,
#  'Flabellidae': 125,
#  'Javania': 126,
#  'stony_corals': 127,
#  'Black_corals': 128,
#  'Antipatharia': 129,
#  'Cladopathidae': 130,
#  'Trissopathes': 131,
#  'Hexapathinae': 132,
#  'Heteropathes': 133,
#  'Schizopathidae': 134,
#  'Alternatipathes': 135,
#  'Alternatipathes_alternata': 136,
#  'Alternatipathes_bipinnata': 137,
#  'Umbellapathes': 138,
#  'Lillipathes': 139,
#  'Dendropathes': 140,
#  'Parantipathes': 141,
#  'Antipathidae': 142,
#  'Antipathes': 143,
#  'black_corals': 144,
#  'Starfish': 145,
#  'Asteroidea': 146,
#  'Asteroidea_sp._1': 147,
#  'Velatida': 148,
#  'Pterasteridae': 149,
#  'Pteraster': 150,
#  'Hymenaster': 151,
#  'Hymenaster_koehleri': 152,
#  'Korethrasteridae': 153,
#  'Peribolaster': 154,
#  'Peribolaster_biserialis': 155,
#  'Myxasteridae': 156,
#  'Asthenactis': 157,
#  'Asthenactis_fisheri': 158,
#  'Asthenactis_papyraceus': 159,
#  'Pythonaster': 160,
#  'Pythonaster_pacificus': 161,
#  'Forcipulatacea': 162,
#  'Forcipulatida': 163,
#  'Zoroasteridae': 164,
#  'Zoroaster': 165,
#  'Zoroaster_spinulosus': 166,
#  'Myxoderma': 167,
#  'Myxoderma_sacculatum': 168,
#  'Myxoderma_platyacanthum': 169,
#  'Asteriidae': 170,
#  'Stylasterias': 171,
#  'Stylasterias_forreri': 172,
#  'Rathbunaster': 173,
#  'Rathbunaster_californicus': 174,
#  'Pycnopodiidae': 175,
#  'Pycnopodia': 176,
#  'Pycnopodia_helianthoides': 177,
#  'Paulasteriidae': 178,
#  'Paulasterias': 179,
#  'Paulasterias_mcclaini': 180,
#  'Brisingida': 181,
#  'Brisingidae': 182,
#  'Brisinga': 183,
#  'Hymenodiscus': 184,
#  'Spinulosacea': 185,
#  'Spinulosida': 186,
#  'Echinasteridae': 187,
#  'Henricia': 188,
#  'Valvatacea': 189,
#  'Valvatida': 190,
#  'Solasteridae': 191,
#  'Lophaster': 192,
#  'Lophaster_furcilliger': 193,
#  'Crossaster': 194,
#  'Crossaster_borealis': 195,
#  'Solaster': 196,
#  'Solaster_hypothrissus': 197,
#  'Heterozonias': 198,
#  'Heterozonias_alternatus': 199,
#  'Goniasteridae': 200,
#  'Mediaster': 201,
#  'Mediaster_aequalis': 202,
#  'Mediaster_tenellus': 203,
#  'Ceramaster': 204,
#  'Hippasterinae': 205,
#  'Hippasteria': 206,
#  'Hippasteria_californica': 207,
#  'Hippasteria_lepidonotus': 208,
#  'Evoplosoma': 209,
#  'Circeaster': 210,
#  'Circeaster_pullus': 211,
#  'Bathyceramaster': 212,
#  'Asterinidae': 213,
#  'Patiria': 214,
#  'Patiria_miniata': 215,
#  'Anseropoda': 216,
#  'Poraniidae': 217,
#  'Poraniopsis': 218,
#  'Poraniopsis_inflata': 219,
#  'Paxillosida': 220,
#  'Astropectinidae': 221,
#  'Astropecten': 222,
#  'Dipsacaster': 223,
#  'Dipsacaster_eximius': 224,
#  'Thrissacanthias': 225,
#  'Thrissacanthias_penicillatus': 226,
#  'Dytaster': 227,
#  'Dytaster_gilberti': 228,
#  'Luidiidae': 229,
#  'Luidia': 230,
#  'Luidia_foliolata': 231,
#  'Radiasteridae': 232,
#  'Radiaster': 233,
#  'Pseudarchasteridae': 234,
#  'Pseudarchaster': 235,
#  'Notomyotida': 236,
#  'Benthopectinidae': 237,
#  'Benthopecten': 238,
#  'Benthopecten_claviger': 239,
#  'starfish': 240,
#  'Sea_pens': 241,
#  'Pennatulacea': 242,
#  'Subsessiliflorae': 243,
#  'Virgulariidae': 244,
#  'Stylatula': 245,
#  'Acanthoptilum': 246,
#  'Virgularia': 247,
#  'Pennatulidae': 248,
#  'Ptilosarcus': 249,
#  'Ptilosarcus_gurneyi': 250,
#  'Pennatula': 251,
#  'Pennatula_phosphorea': 252,
#  'Sessiliflorae': 253,
#  'Anthoptilidae': 254,
#  'Anthoptilum': 255,
#  'Anthoptilum_grandiflorum': 256,
#  'Anthoptilum_lithophilum': 257,
#  'Umbellulidae': 258,
#  'Umbellula': 259,
#  'Umbellula_sp._2': 260,
#  'Umbellula_sp._1': 261,
#  'Protoptilidae': 262,
#  'Distichoptilum': 263,
#  'Distichoptilum_gracile': 264,
#  'Protoptilum': 265,
#  'Protoptilum_sp._1': 266,
#  'Kophobelemnidae': 267,
#  'Kophobelemnon': 268,
#  'Kophobelemnon_sp._1': 269,
#  'Funiculinidae': 270,
#  'Funiculina': 271,
#  'Funiculina-Balticina_complex': 272,
#  'Pennatulacea_sp._1': 273,
#  'sea_pens': 274,
#  'Sea_anemones': 275,
#  'Actiniaria': 276,
#  'Enthemonae': 277,
#  'Actinostoloidea': 278,
#  'Actinostolidae': 279,
#  'Stomphia': 280,
#  'Stomphia_didemon': 281,
#  'Sicyonis': 282,
#  'Sicyonis_careyi': 283,
#  'Exocoelactinidae': 284,
#  'Exocoelactis': 285,
#  'Actinioidea': 286,
#  'Liponematidae': 287,
#  'Liponema': 288,
#  'Liponema_brevicorne': 289,
#  'Actiniidae': 290,
#  'Urticina': 291,
#  'Dofleinia': 292,
#  'Bolocera': 293,
#  'Bolocera_kensmithi': 294,
#  'Actiniidae_sp._1': 295,
#  'Isosicyonis': 296,
#  'Iosactinidae': 297,
#  'Iosactis': 298,
#  'Iosactis_vagabunda': 299,
#  'Metridioidea': 300,
#  'Hormathiidae': 301,
#  'Hormathiidae_sp._1': 302,
#  'Actinauge': 303,
#  'Actinauge_verrillii': 304,
#  'Hormathia': 305,
#  'Actinoscyphiidae': 306,
#  'Actinoscyphia': 307,
#  'Metridiidae': 308,
#  'Metridium': 309,
#  'Metridium_farcimen': 310,
#  'Bathyphellidae': 311,
#  'Bathyphellia': 312,
#  'Bathyphellia_australis': 313,
#  'Ostiactinidae': 314,
#  'Ostiactis': 315,
#  'Ostiactis_pearseae': 316,
#  'Anenthemonae': 317,
#  'Actinernoidea': 318,
#  'Actinernidae': 319,
#  'Actinernus': 320,
#  'Edwardsioidea': 321,
#  'Edwardsiidae': 322,
#  'sea_anemones': 323,
#  'Demosponges': 324,
#  'Demospongiae': 325,
#  'Poecilosclerida': 326,
#  'Cladorhizidae': 327,
#  'Asbestopluma': 328,
#  'Asbestopluma_monticola': 329,
#  'Asbestopluma_rickettsi': 330,
#  'Chondrocladia': 331,
#  'Chondrocladia_sp._A': 332,
#  'Chondrocladia_sp._4': 333,
#  'Cladorhiza': 334,
#  'Cladorhizidae_sp._A': 335,
#  'Mycalidae': 336,
#  'Mycale': 337,
#  'Mycale_sp._2': 338,
#  'Mycale_sp._1': 339,
#  'Hadromerida': 340,
#  'Polymastiidae': 341,
#  'Polymastia': 342,
#  'Astrophorida': 343,
#  'Theneidae': 344,
#  'Thenea': 345,
#  'Thenea_muricata': 346,
#  'demosponges': 347,
#  'Glass_sponges': 348,
#  'Hexactinellida': 349,
#  'Amphidiscophora': 350,
#  'Amphidiscosida': 351,
#  'Hyalonematidae': 352,
#  'Hyalonema': 353,
#  'Hexasterophora': 354,
#  'Lyssacinosida': 355,
#  'Euplectellidae': 356,
#  'Corbitellinae': 357,
#  'Atlantisella': 358,
#  'Regadrella': 359,
#  'Dictyocalyx': 360,
#  'Euplectellinae': 361,
#  'Euplectella': 362,
#  'Docosaccus': 363,
#  'Docosaccus_maculatus': 364,
#  'Bolosominae': 365,
#  'Saccocalyx': 366,
#  'Saccocalyx_pedunculatus': 367,
#  'Amphidiscella': 368,
#  'Rossellidae': 369,
#  'Acanthascinae': 370,
#  'Staurocalyptus': 371,
#  'Staurocalyptus_solidus': 372,
#  'Acanthascinae_sp._4': 373,
#  'Acanthascinae_sp._1-4_complex': 374,
#  'Acanthascinae_sp._2': 375,
#  'Rossellinae': 376,
#  'Caulophacus': 377,
#  'Bathydorus': 378,
#  'Bathydorus_laniger': 379,
#  'Bathydorus_laevis_pseudospinosus': 380,
#  'Bathydorus_sp._1': 381,
#  'Lyssacinosida_sp._1': 382,
#  'Hexactinosida': 383,
#  'Tretodictyidae': 384,
#  'Hexactinella': 385,
#  'Sclerothamnopsis': 386,
#  'Farreidae': 387,
#  'Farrea': 388,
#  'Farrea_occa': 389,
#  'Farrea_truncata_complex': 390,
#  'Aphrocallistidae': 391,
#  'Heterochone': 392,
#  'Heterochone_calyx': 393,
#  'Euretidae': 394,
#  'Chonelasmatinae': 395,
#  'Chonelasma': 396,
#  'Chonelasmatinae_sp._1': 397,
#  'yellow_ruffled_sponge': 398,
#  'Hexactinellida_sp._1': 399,
#  'Hexactinellida_sp._2': 400,
#  'Hexactinellida_sp._3': 401,
#  'Hexactinellida_sp._4': 402,
#  'Hexactinellida_sp._6': 403,
#  'glass_sponges': 404,
#  'Sea_urchins': 405,
#  'Echinoidea': 406,
#  'Cidaroidea': 407,
#  'Cidaroida': 408,
#  'Cidaridae': 409,
#  'Aporocidaris': 410,
#  'Aporocidaris_milleri': 411,
#  'Euechinoidea': 412,
#  'Echinothurioida': 413,
#  'Echinothuriidae': 414,
#  'Tromikosoma': 415,
#  'Tromikosoma_panamense': 416,
#  'Tromikosoma_hispidum': 417,
#  'Irregularia': 418,
#  'Atelostomata': 419,
#  'Cassiduloida': 420,
#  'Holasterina': 421,
#  'Pourtalesiidae': 422,
#  'Echinocrepis': 423,
#  'Echinocrepis_rostrata': 424,
#  'Cystechinus': 425,
#  'Cystechinus_loveni': 426,
#  'Cystechinus_giganteus': 427,
#  'Cystocrepis': 428,
#  'Cystocrepis_setigera': 429,
#  'Spatangoida': 430,
#  'Schizasteridae': 431,
#  'Brisaster': 432,
#  'Holasteroida': 433,
#  'Urechinina': 434,
#  'Urechinidae': 435,
#  'Pilematechinus': 436,
#  'Carinacea': 437,
#  'Echinacea': 438,
#  'Camarodonta': 439,
#  'Echinidea': 440,
#  'Odontophora': 441,
#  'Strongylocentrotidae': 442,
#  'Strongylocentrotus': 443,
#  'Strongylocentrotus_fragilis': 444,
#  'sea_urchins': 445,
#  'other': -1}

# %%
def parse(d, image_list, annotation_list):
    details = d['annotation']
    #settle image
    fname = details['filename']
    iw = int(details['size']['width'])
    ih = int(details['size']['height'])
    id = len(image_list)
    new_image = dict(
        id=id,
        width=iw,
        height=ih,
        file_name=fname
    )
    image_list.append(new_image)

    # settle annotations
    annotations = details["object"]
    if not isinstance(annotations, list):
        annotations = [annotations]

    for a in annotations:
        cid = concept_id_lkup.get(a["name"]) or -1
        xmin = int(a['bndbox']['xmin'])
        xmax = int(a['bndbox']['xmax'])
        ymin = int(a['bndbox']['ymin'])
        ymax = int(a['bndbox']['ymax'])

        if ymax <= ymin or xmax <= xmin:
            print(f"bad bound box: {fname}")
            continue
        ah = ymax - ymin
        aw = xmax - xmin
        bbox = [xmin, ymin, aw, ah]
        segmentation = [[xmin, ymin, xmax, ymin, xmax, ymax, xmin, ymax]]
        annotation_list.append(
            dict(
                id=len(annotation_list),
                image_id=id,
                category_id=cid,
                area=ah*aw,
                segmentation=segmentation,
                bbox=bbox,
                iscrowd=0
            )
        )

# %%
images = []
annotations = []
for d in xml_dicts:
    parse(d, images, annotations)
# Out:
# bad bound box: 7abba8d5-c7a7-4c62-bdf8-fb89f65ec7cf.png
# bad bound box: d48a1532-ee0c-400e-83cf-ca9ad4653797.png
# bad bound box: 8b53ad8b-4aa6-4a4e-be55-aa5cb839e9e7.png
# bad bound box: 2536ba44-59a0-46e5-85ff-8ff963f1b3ae.png
# bad bound box: 7c4ddd91-6c5e-48c7-9465-803c4440f705.png
# bad bound box: b5925d24-d898-4305-b4bc-8d191f2350c6.png
# bad bound box: 41e20e36-715b-467c-b6b7-e7770fa934be.png
# bad bound box: 8fbad6f7-db16-4348-b253-4c78eca4641a.png
# bad bound box: 845296fb-514d-4c61-91cf-172b6b511b3e.png
# bad bound box: 845296fb-514d-4c61-91cf-172b6b511b3e.png
# bad bound box: ac4a1d23-99d8-4d8a-885c-b6b9573ffa84.png
# bad bound box: 677dd1d0-192e-43b4-b992-024854928624.png
# bad bound box: 3e38e8c0-5f76-4071-8b5d-8edc5754ded3.png
# bad bound box: 23b8a279-f53b-409c-bb0c-61ae8146ddc7.png
# bad bound box: 23b8a279-f53b-409c-bb0c-61ae8146ddc7.png
# bad bound box: 23b8a279-f53b-409c-bb0c-61ae8146ddc7.png
# bad bound box: 82893cf6-3360-45b4-bda3-1053cef01db4.png
# bad bound box: 82893cf6-3360-45b4-bda3-1053cef01db4.png
# bad bound box: 4944db74-85ba-459b-828f-845a655e8e8c.png
# bad bound box: 4944db74-85ba-459b-828f-845a655e8e8c.png
# bad bound box: e58a1935-7044-4772-ad55-71aa7cf8e822.png
# bad bound box: e58a1935-7044-4772-ad55-71aa7cf8e822.png
# bad bound box: e58a1935-7044-4772-ad55-71aa7cf8e822.png
# bad bound box: e58a1935-7044-4772-ad55-71aa7cf8e822.png
# bad bound box: e58a1935-7044-4772-ad55-71aa7cf8e822.png
# bad bound box: e58a1935-7044-4772-ad55-71aa7cf8e822.png
# bad bound box: b6457530-0f8f-4bdd-ad4f-fdf8960622ab.png
# bad bound box: 5f580eb9-30a6-4b35-9914-e72ad44f495a.png
# bad bound box: d1eb903b-1bf4-4f23-8684-53cc6d9e052b.png
# bad bound box: bcefc23e-9cdb-4a28-b40b-3c0d736c10f9.png
# bad bound box: 8fc81af2-bf72-46ca-b894-8ca6ff11bc39.png
# bad bound box: 8fc81af2-bf72-46ca-b894-8ca6ff11bc39.png
# bad bound box: 8fc81af2-bf72-46ca-b894-8ca6ff11bc39.png
# bad bound box: 2e3fe2b7-bc00-4472-9142-4da87021cca7.png

# %%
coco_all = dict(
    info=info,
    licenses=licenses,
    categories=categories,
    supercategories=supercategories,
    images=images,
    annotations=annotations,
)

# %%
import json

json.dump(coco_all, open("coco.json", "w"), indent=4)
